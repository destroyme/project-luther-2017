# %%
# Modeling
import statsmodels.api as sm
import statsmodels.formula.api as smf
import patsy
from sklearn.linear_model import LinearRegression
from sklearn.linear_model import RidgeCV

# Using PolynomialFeatures and make_pipeline for Polynomial Regression
from sklearn.preprocessing import PolynomialFeatures
from sklearn.pipeline import make_pipeline

# Data wrangling
import pandas as pd
import numpy as np
import re

# Time
import time
import datetime
from datetime import datetime as dt
import dateutil.parser

# Plotting
# import matplotlib.pyplot as plt
import seaborn as sns
from seaborn import plt

# URL Grabbing
import requests

# Scraping / Searching
from bs4 import BeautifulSoup
import re

# Misc
import pickle
from pprint import pprint

# %matplotlib inline
pd.set_option('display.float_format', lambda x: '%.2f' % x) # reduces the amount of decimals when printing the df's

# %%
    with open("movies.pkl", 'rb') as picklefile: 
        df = pickle.load(picklefile)

# %%
# just check on the data
df.head().T
# Out:
#                                                             0  \
# index                  The Other Side of the Mountain Part II
# actors                                                    NaN
# close_date                                                NaT
# composers                                                 NaN
# days_in_theater                                           NaN
# directors                                                 NaN
# domestic_gross_adj                                42753500.00
# foreign_unadj                                             NaN
# genre                                                 Romance
# mpaa_rating                                                PG
# number_of_theaters                                        NaN
# opening_weekend_adj                                       NaN
# producers                                                 NaN
# production_budget_adj                                     NaN
# release_date                              1978-01-01 00:00:00
# runtime                                                100.00
# worldwide_gross_unadj                                     NaN
# writers                                                   NaN
#
#                                                              1  \
# index                                        Universal Soldier
# actors                 [Jean-Claude Van Damme, Dolph Lundgren]
# close_date                                                 NaT
# composers                                        [Tim Simonec]
# days_in_theater                                            NaN
# directors                                    [Roland Emmerich]
# domestic_gross_adj                                 75661200.00
# foreign_unadj                                              NaN
# genre                                            Sci-Fi Action
# mpaa_rating                                                  R
# number_of_theaters                                     1925.00
# opening_weekend_adj                                20962400.00
# producers                                                  NaN
# production_budget_adj                                      NaN
# release_date                               1992-07-10 00:00:00
# runtime                                                 102.00
# worldwide_gross_unadj                                      NaN
# writers                                          [Dean Devlin]
#
#                                          2                    3  \
# index                              Newtown       Mommie Dearest
# actors                                 NaN                  NaN
# close_date                             NaT                  NaT
# composers                              NaN                  NaN
# days_in_theater                      14.00                  NaN
# directors                              NaN                  NaN
# domestic_gross_adj                13900.00          59219100.00
# foreign_unadj                          NaN                  NaN
# genre                          Documentary                Drama
# mpaa_rating                        Unrated                   PG
# number_of_theaters                    3.00                  NaN
# opening_weekend_adj                6700.00                  NaN
# producers                              NaN                  NaN
# production_budget_adj                  NaN                  NaN
# release_date           2016-10-07 00:00:00  1981-09-18 00:00:00
# runtime                              85.00               129.00
# worldwide_gross_unadj                  NaN                  NaN
# writers                                NaN                  NaN
#
#                                                       4
# index                                            G.B.F.
# actors                 [Natasha Lyonne, Megan Mullally]
# close_date                                          NaT
# composers                                           NaN
# days_in_theater                                     NaN
# directors                                           NaN
# domestic_gross_adj                                  NaN
# foreign_unadj                                       NaN
# genre                                            Comedy
# mpaa_rating                                           R
# number_of_theaters                                  NaN
# opening_weekend_adj                                 NaN
# producers                                           NaN
# production_budget_adj                               NaN
# release_date                        2014-01-17 00:00:00
# runtime                                           93.00
# worldwide_gross_unadj                               NaN
# writers                                             NaN

# %%
# get all the crew members & related data
df_crew = (df[['index', 'actors', 'composers', 'directors', 'producers',
               'writers', 'domestic_gross_adj', 'release_date', 'production_budget_adj']])

# %%
df_crew.head().T
# Out:
#                                                             0  \
# index                  The Other Side of the Mountain Part II
# actors                                                    NaN
# composers                                                 NaN
# directors                                                 NaN
# producers                                                 NaN
# writers                                                   NaN
# domestic_gross_adj                                42753500.00
# release_date                              1978-01-01 00:00:00
# production_budget_adj                                     NaN
#
#                                                              1  \
# index                                        Universal Soldier
# actors                 [Jean-Claude Van Damme, Dolph Lundgren]
# composers                                        [Tim Simonec]
# directors                                    [Roland Emmerich]
# producers                                                  NaN
# writers                                          [Dean Devlin]
# domestic_gross_adj                                 75661200.00
# release_date                               1992-07-10 00:00:00
# production_budget_adj                                      NaN
#
#                                          2                    3  \
# index                              Newtown       Mommie Dearest
# actors                                 NaN                  NaN
# composers                              NaN                  NaN
# directors                              NaN                  NaN
# producers                              NaN                  NaN
# writers                                NaN                  NaN
# domestic_gross_adj                13900.00          59219100.00
# release_date           2016-10-07 00:00:00  1981-09-18 00:00:00
# production_budget_adj                  NaN                  NaN
#
#                                                       4
# index                                            G.B.F.
# actors                 [Natasha Lyonne, Megan Mullally]
# composers                                           NaN
# directors                                           NaN
# producers                                           NaN
# writers                                             NaN
# domestic_gross_adj                                  NaN
# release_date                        2014-01-17 00:00:00
# production_budget_adj                               NaN

# %%
# checking if there are any multiple crew memebers in a column
def checkLargeCrew(crew):
    if isinstance(crew, list):
        if len(crew) > 1:
            return True
        else:
            return False
    else:
        return False

df[df['actors'].apply(checkLargeCrew)].T
# Out:
#                                                           1     \
# index                                        Universal Soldier
# actors                 [Jean-Claude Van Damme, Dolph Lundgren]
# close_date                                                 NaT
# composers                                        [Tim Simonec]
# days_in_theater                                            NaN
# directors                                    [Roland Emmerich]
# domestic_gross_adj                                 75661200.00
# foreign_unadj                                              NaN
# genre                                            Sci-Fi Action
# mpaa_rating                                                  R
# number_of_theaters                                     1925.00
# opening_weekend_adj                                20962400.00
# producers                                                  NaN
# production_budget_adj                                      NaN
# release_date                               1992-07-10 00:00:00
# runtime                                                 102.00
# worldwide_gross_unadj                                      NaN
# writers                                          [Dean Devlin]
#
#                                                    4     \
# index                                            G.B.F.
# actors                 [Natasha Lyonne, Megan Mullally]
# close_date                                          NaT
# composers                                           NaN
# days_in_theater                                     NaN
# directors                                           NaN
# domestic_gross_adj                                  NaN
# foreign_unadj                                       NaN
# genre                                            Comedy
# mpaa_rating                                           R
# number_of_theaters                                  NaN
# opening_weekend_adj                                 NaN
# producers                                           NaN
# production_budget_adj                               NaN
# release_date                        2014-01-17 00:00:00
# runtime                                           93.00
# worldwide_gross_unadj                               NaN
# writers                                             NaN
#
#                                                7     \
# index                                    The Jackal
# actors                 [Richard Gere, Bruce Willis]
# close_date                                      NaT
# composers                          [Carter Burwell]
# days_in_theater                                 NaN
# directors                     [Michael Caton-Jones]
# domestic_gross_adj                     103517800.00
# foreign_unadj                          104400000.00
# genre                               Action Thriller
# mpaa_rating                                       R
# number_of_theaters                          2309.00
# opening_weekend_adj                     28578200.00
# producers                             [Mark Gordon]
# production_budget_adj                   60000000.00
# release_date                    1997-11-14 00:00:00
# runtime                                      125.00
# worldwide_gross_unadj                  159330280.00
# writers                                         NaN
#
#                                                                     10    \
# index                        Talladega Nights: The Ballad of Ricky Bobby
# actors                 [Will Ferrell, John C. Reilly, Sacha Baron Coh...
# close_date                                           2006-10-15 00:00:00
# composers                                                  [Alex Wurman]
# days_in_theater                                                    77.00
# directors                                                   [Adam McKay]
# domestic_gross_adj                                          195732200.00
# foreign_unadj                                                14752800.00
# genre                                                      Sports Comedy
# mpaa_rating                                                        PG-13
# number_of_theaters                                               3807.00
# opening_weekend_adj                                          62124500.00
# producers                      [Judd Apatow, Ryan Kavanaugh, Adam McKay]
# production_budget_adj                                         5000000.00
# release_date                                         2006-08-04 00:00:00
# runtime                                                           110.00
# worldwide_gross_unadj                                       162966177.00
# writers                                       [Will Ferrell, Adam McKay]
#
#                                                11    \
# index                                 Me Before You
# actors                 [Emilia Clarke, Sam Claflin]
# close_date                      2016-08-18 00:00:00
# composers                                       NaN
# days_in_theater                               77.00
# directors                                       NaN
# domestic_gross_adj                      55815700.00
# foreign_unadj                          151700000.00
# genre                                       Romance
# mpaa_rating                                   PG-13
# number_of_theaters                          2762.00
# opening_weekend_adj                     18551700.00
# producers                                       NaN
# production_budget_adj                   20000000.00
# release_date                    2016-06-03 00:00:00
# runtime                                      110.00
# worldwide_gross_unadj                  207945075.00
# writers                                         NaN
#
#                                                          13    \
# index                                                Cruising
# actors                 [Al Pacino, Paul Sorvino, Karen Allen]
# close_date                                                NaT
# composers                                                 NaN
# days_in_theater                                           NaN
# directors                                  [William Friedkin]
# domestic_gross_adj                                63618400.00
# foreign_unadj                                             NaN
# genre                                                Thriller
# mpaa_rating                                                 R
# number_of_theaters                                        NaN
# opening_weekend_adj                                       NaN
# producers                                                 NaN
# production_budget_adj                                     NaN
# release_date                              1980-02-15 00:00:00
# runtime                                                106.00
# worldwide_gross_unadj                                     NaN
# writers                                    [William Friedkin]
#
#                                                                 14    \
# index                                    ABCD (Any Body Can Dance) 2
# actors                 [Varun Dhawan, Prabhu Dheva, Shraddha Kapoor]
# close_date                                       2015-07-16 00:00:00
# composers                                                        NaN
# days_in_theater                                                28.00
# directors                                             [Remo D'Souza]
# domestic_gross_adj                                         935400.00
# foreign_unadj                                                    NaN
# genre                                                        Musical
# mpaa_rating                                                  Unrated
# number_of_theaters                                            146.00
# opening_weekend_adj                                        465700.00
# producers                                                        NaN
# production_budget_adj                                            NaN
# release_date                                     2015-06-19 00:00:00
# runtime                                                       154.00
# worldwide_gross_unadj                                      892133.00
# writers                                                          NaN
#
#                                                                     18    \
# index                                                              Alfie
# actors                 [Jude Law, Marisa Tomei, Susan Sarandon, Nia L...
# close_date                                           2005-01-13 00:00:00
# composers                                                  [John Powell]
# days_in_theater                                                    70.00
# directors                                                [Charles Shyer]
# domestic_gross_adj                                           18664000.00
# foreign_unadj                                                21750734.00
# genre                                                     Comedy / Drama
# mpaa_rating                                                            R
# number_of_theaters                                               2215.00
# opening_weekend_adj                                           8661600.00
# producers                                                [Charles Shyer]
# production_budget_adj                                        60000000.00
# release_date                                         2004-11-05 00:00:00
# runtime                                                           102.00
# worldwide_gross_unadj                                        35150546.00
# writers                                                  [Charles Shyer]
#
#                                               21                         23    \
# index                                   Hot Shots!               Chain Letter
# actors                 [Charlie Sheen, Cary Elwes]  [Nikki Reed, Keith David]
# close_date                                     NaT        2010-10-07 00:00:00
# composers                                      NaN                        NaN
# days_in_theater                                NaN                        NaN
# directors                           [Jim Abrahams]                        NaN
# domestic_gross_adj                    142730400.00                  149900.00
# foreign_unadj                         111628547.00                  446574.00
# genre                                       Comedy            Horror Thriller
# mpaa_rating                                  PG-13                          R
# number_of_theaters                         1999.00                     406.00
# opening_weekend_adj                    22289000.00                  149900.00
# producers                          [Bill Badalato]                        NaN
# production_budget_adj                  26000000.00                 3000000.00
# release_date                   1991-07-31 00:00:00        2010-10-01 00:00:00
# runtime                                      84.00                      96.00
# worldwide_gross_unadj                 181096164.00                  585362.00
# writers                             [Jim Abrahams]                        NaN
#
#                                       ...                  \
# index                                 ...
# actors                                ...
# close_date                            ...
# composers                             ...
# days_in_theater                       ...
# directors                             ...
# domestic_gross_adj                    ...
# foreign_unadj                         ...
# genre                                 ...
# mpaa_rating                           ...
# number_of_theaters                    ...
# opening_weekend_adj                   ...
# producers                             ...
# production_budget_adj                 ...
# release_date                          ...
# runtime                               ...
# worldwide_gross_unadj                 ...
# writers                               ...
#
#                                              9935  \
# index                             She's So Lovely
# actors                 [Sean Penn, John Travolta]
# close_date                                    NaT
# composers                                     NaN
# days_in_theater                               NaN
# directors                       [Nick Cassavetes]
# domestic_gross_adj                    13722100.00
# foreign_unadj                                 NaN
# genre                             Romantic Comedy
# mpaa_rating                                     R
# number_of_theaters                         844.00
# opening_weekend_adj                    5691300.00
# producers                                     NaN
# production_budget_adj                         NaN
# release_date                  1997-08-27 00:00:00
# runtime                                     96.00
# worldwide_gross_unadj                         NaN
# writers                                       NaN
#
#                                                                     9938  \
# index                                                       Ride Along 2
# actors                 [Kevin Hart, Ice Cube, Benjamin Bratt, Olivia ...
# close_date                                           2016-06-16 00:00:00
# composers                                                            NaN
# days_in_theater                                                   154.00
# directors                                                    [Tim Story]
# domestic_gross_adj                                           91957900.00
# foreign_unadj                                                33383467.00
# genre                                                      Action Comedy
# mpaa_rating                                                        PG-13
# number_of_theaters                                               3192.00
# opening_weekend_adj                                          35530600.00
# producers                                        [Ice Cube, Will Packer]
# production_budget_adj                                        40000000.00
# release_date                                         2016-01-15 00:00:00
# runtime                                                           101.00
# worldwide_gross_unadj                                       124605297.00
# writers                                        [Phil Hay, Matt Manfredi]
#
#                                                                     9939  \
# index                                  Big Mommas: Like Father, Like Son
# actors                 [Martin Lawrence, Brandon T. Jackson, Portia D...
# close_date                                           2011-05-26 00:00:00
# composers                                                            NaN
# days_in_theater                                                    98.00
# directors                                               [John Whitesell]
# domestic_gross_adj                                           41726300.00
# foreign_unadj                                                44770652.00
# genre                                                      Action Comedy
# mpaa_rating                                                        PG-13
# number_of_theaters                                               2821.00
# opening_weekend_adj                                          17939200.00
# producers                                                [Arnon Milchan]
# production_budget_adj                                        32000000.00
# release_date                                         2011-02-18 00:00:00
# runtime                                                           107.00
# worldwide_gross_unadj                                        82686066.00
# writers                                      [Matthew Fogel, Don Rhymer]
#
#                                                                     9942  \
# index                                                      Trust the Man
# actors                 [Julianne Moore, David Duchovny, Billy Crudup,...
# close_date                                           2006-10-08 00:00:00
# composers                                                [Clint Mansell]
# days_in_theater                                                    56.00
# directors                                              [Bart Freundlich]
# domestic_gross_adj                                            2021200.00
# foreign_unadj                                                 5822583.00
# genre                                                    Romantic Comedy
# mpaa_rating                                                            R
# number_of_theaters                                                260.00
# opening_weekend_adj                                            238100.00
# producers                                                [Sidney Kimmel]
# production_budget_adj                                                NaN
# release_date                                         2006-08-18 00:00:00
# runtime                                                           103.00
# worldwide_gross_unadj                                         7353118.00
# writers                                                [Bart Freundlich]
#
#                                                                9945  \
# index                                                     Boomerang
# actors                 [Eddie Murphy, Halle Berry, Martin Lawrence]
# close_date                                                      NaT
# composers                                           [Marcus Miller]
# days_in_theater                                                 NaN
# directors                                                       NaN
# domestic_gross_adj                                     146012900.00
# foreign_unadj                                           61000000.00
# genre                                               Romantic Comedy
# mpaa_rating                                                       R
# number_of_theaters                                          2145.00
# opening_weekend_adj                                     28431800.00
# producers                                            [Brian Grazer]
# production_budget_adj                                   42000000.00
# release_date                                    1992-07-01 00:00:00
# runtime                                                      117.00
# worldwide_gross_unadj                                  131052444.00
# writers                                                         NaN
#
#                                                                     9954  \
# index                                                           Shopping
# actors                 [Sadie Frost, Jude Law, Sean Pertwee, Sean Bea...
# close_date                                                           NaT
# composers                                                            NaN
# days_in_theater                                                      NaN
# directors                                           [Paul W.S. Anderson]
# domestic_gross_adj                                               6000.00
# foreign_unadj                                                        NaN
# genre                                                                NaN
# mpaa_rating                                                            R
# number_of_theaters                                                  1.00
# opening_weekend_adj                                              3900.00
# producers                                                  [Jeremy Bolt]
# production_budget_adj                                                NaN
# release_date                                         1996-02-09 00:00:00
# runtime                                                            88.00
# worldwide_gross_unadj                                                NaN
# writers                                             [Paul W.S. Anderson]
#
#                                                                     9955  \
# index                                            The Talented Mr. Ripley
# actors                 [Matt Damon, Gwyneth Paltrow, Jude Law, Cate B...
# close_date                                                           NaT
# composers                                                [Gabriel Yared]
# days_in_theater                                                      NaN
# directors                                            [Anthony Minghella]
# domestic_gross_adj                                          133151200.00
# foreign_unadj                                                47500000.00
# genre                                                           Thriller
# mpaa_rating                                                            R
# number_of_theaters                                               2369.00
# opening_weekend_adj                                          21690100.00
# producers                                               [Sydney Pollack]
# production_budget_adj                                        40000000.00
# release_date                                         1999-12-25 00:00:00
# runtime                                                           139.00
# worldwide_gross_unadj                                       128798265.00
# writers                                                              NaN
#
#                                                                     9959  \
# index                                                              Logan
# actors                 [Hugh Jackman, Patrick Stewart, Richard E. Gra...
# close_date                                                           NaT
# composers                                               [Marco Beltrami]
# days_in_theater                                                    41.00
# directors                                                [James Mangold]
# domestic_gross_adj                                          219343600.00
# foreign_unadj                                               377548381.00
# genre                                                 Action / Adventure
# mpaa_rating                                                            R
# number_of_theaters                                               4071.00
# opening_weekend_adj                                          88411900.00
# producers              [Lauren Schuler Donner, Simon Kinberg, Hutch P...
# production_budget_adj                                        97000000.00
# release_date                                         2017-03-03 00:00:00
# runtime                                                           135.00
# worldwide_gross_unadj                                       596892028.00
# writers                      [Scott Frank, Michael Green, James Mangold]
#
#                                                        9960  \
# index                                     Fruitvale Station
# actors                 [Michael B. Jordan, Octavia Spencer]
# close_date                              2013-10-31 00:00:00
# composers                                [Ludwig Goransson]
# days_in_theater                                      112.00
# directors                                    [Ryan Coogler]
# domestic_gross_adj                              17757200.00
# foreign_unadj                                    1284491.00
# genre                                                 Drama
# mpaa_rating                                               R
# number_of_theaters                                  1086.00
# opening_weekend_adj                                     NaN
# producers                                 [Forest Whitaker]
# production_budget_adj                                   NaN
# release_date                            2013-07-12 00:00:00
# runtime                                               90.00
# worldwide_gross_unadj                           17385830.00
# writers                                      [Ryan Coogler]
#
#                                                      9961
# index                                             Beloved
# actors                     [Danny Glover, Thandie Newton]
# close_date                                            NaT
# composers                                [Rachel Portman]
# days_in_theater                                       NaN
# directors                                [Jonathan Demme]
# domestic_gross_adj                            41695800.00
# foreign_unadj                                         NaN
# genre                                        Period Drama
# mpaa_rating                                             R
# number_of_theaters                                1571.00
# opening_weekend_adj                           15060100.00
# producers                                 [Gary Goetzman]
# production_budget_adj                         80000000.00
# release_date                          1998-10-16 00:00:00
# runtime                                            172.00
# worldwide_gross_unadj                                 NaN
# writers                [Adam Brooks, Richard LaGravenese]
#
# [18 rows x 3445 columns]

# %%
crewcount = df_crew['composers'].dropna().apply(lambda r: len(r[0])).sum()
crewcount
# Out:
# 34669

# %%
"""
This cell creates the crew data frame that can be joined with the core data frame.
"""

# preparing the dataframe
crew = (pd.DataFrame(columns=['name','role','movie','domestic_gross_adj','release_date','production_budget_adj']))

def makeRow(row):
    global crew
    
#     print(row)
    
    movie = row[0]
    domestic_gross_adj = row[6]
    release_date = row[7]
    prod_budget = row[8]

    for index, role in enumerate(row[1:6]):
        if index == 0:
            rrole = 'actor'
        elif index == 1:
            rrole = 'composer'
        elif index == 2:
            rrole = 'director'
        elif index == 3:
            rrole = 'producer'
        elif index == 4:
            rrole = 'writer'
        
        if isinstance(role, list):
            for name in role:
                frame = pd.DataFrame(data={'name' : [name],
                                           'role' : [rrole],
                                           'movie' : [movie],
                                           'domestic_gross_adj' : [domestic_gross_adj],
                                           'release_date' : [release_date],
                                           'production_budget_adj' : [prod_budget]},
                                     columns=['name','role','movie','domestic_gross_adj','release_date', 'production_budget_adj'])
            crew = pd.concat([crew, frame])

(df_crew
#  .iloc[:10,:] # used for testing
 .apply(makeRow, axis=1));

# %%
# save the data frame! :)
# crew.to_pickle('crew.pkl')

# %%
crew.groupby(['role']).count()
# Out:
#           name  movie  domestic_gross_adj  release_date  production_budget_adj
# role
# actor     4648   4648                4493          4614                   2101
# composer  2552   2552                2523          2549                   1492
# director  3491   3491                3367          3459                   1778
# producer  2926   2926                2850          2901                   1692
# writer    2375   2375                2309          2358                   1398

# %%
crew.tail().T
# Out:
#                                          0                    0  \
# name                        Thandie Newton       Rachel Portman
# role                                 actor             composer
# movie                              Beloved              Beloved
# domestic_gross_adj             41695800.00          41695800.00
# release_date           1998-10-16 00:00:00  1998-10-16 00:00:00
# production_budget_adj          80000000.00          80000000.00
#
#                                          0                    0  \
# name                        Jonathan Demme        Gary Goetzman
# role                              director             producer
# movie                              Beloved              Beloved
# domestic_gross_adj             41695800.00          41695800.00
# release_date           1998-10-16 00:00:00  1998-10-16 00:00:00
# production_budget_adj          80000000.00          80000000.00
#
#                                          0
# name                   Richard LaGravenese
# role                                writer
# movie                              Beloved
# domestic_gross_adj             41695800.00
# release_date           1998-10-16 00:00:00
# production_budget_adj          80000000.00

# %%
crew.domestic_gross_adj.describe()
# Out:
# count         3905.00
# mean     138538153.52
# std      144175199.24
# min          27600.00
# 25%       44994700.00
# 50%       90505200.00
# 75%      177586000.00
# max     1234649200.00
# Name: domestic_gross_adj, dtype: float64

# %%
crew.production_budget_adj.describe()
# Out:
# count        3905.00
# mean     72688860.44
# std      57530210.71
# min       1000000.00
# 25%      28000000.00
# 50%      60000000.00
# 75%     100000000.00
# max     300000000.00
# Name: production_budget_adj, dtype: float64

# %%
# look for films that made N times the amount of the budget
topcrew = (crew[crew[['domestic_gross_adj', 'production_budget_adj']]
            .apply(axis=1, func=lambda r: True if r[0] > r[1]*4 else False)]
            .sort_values('domestic_gross_adj', ascending=False))

# %%
# taking a peek into the data
topcrew[topcrew['role'] == 'director'].sort_values('domestic_gross_adj', ascending=False);
# Out:
#                                 name      role  \
# 0                       George Lucas  director
# 0                      James Cameron  director
# 0                   Steven Spielberg  director
# 0                   Steven Spielberg  director
# 0                   Steven Spielberg  director
# 0                       George Lucas  director
# 0                    Colin Trevorrow  director
# 0                     Irvin Kershner  director
# 0                    Robert Zemeckis  director
# 0                   Steven Spielberg  director
# 0                        Rob Minkoff  director
# 0                      Conrad Vernon  director
# 0                          Sam Raimi  director
# 0                    Roland Emmerich  director
# 0                       Ivan Reitman  director
# 0                     Chris Columbus  director
# 0                         Tim Burton  director
# 0                      Peter Jackson  director
# 0                         Mel Gibson  director
# 0                       George Lucas  director
# 0                    Robert Zemeckis  director
# 0                 M. Night Shyamalan  director
# 0                     Richard Donner  director
# 0                      Peter Jackson  director
# 0                     Sydney Pollack  director
# 0                        Lee Unkrich  director
# 0                         Jan DeBont  director
# 0                   Barry Sonnenfeld  director
# 0                      Peter Jackson  director
# 0                   Steven Spielberg  director
# ..                               ...       ...
# 0                         Mike Leigh  director
# 0                         Steve Carr  director
# 0                    Lisa Cholodenko  director
# 0                        Stacy Title  director
# 0                           Eli Roth  director
# 0                          Rob Hardy  director
# 0                       Adam Wingard  director
# 0                    Michael Hoffman  director
# 0                      Ricky Gervais  director
# 0                          Billy Ray  director
# 0                    Kimberly Peirce  director
# 0                     Michael Tiddes  director
# 0                    Morgan Spurlock  director
# 0                        Dax Shepard  director
# 0                            Ang Lee  director
# 0   Florian Henckel von Donnersmarck  director
# 0                    Damien Chazelle  director
# 0                      Michael Moore  director
# 0                        Jeff Wadlow  director
# 0                      Alex Kendrick  director
# 0                        Neil Jordan  director
# 0                   Derek Cianfrance  director
# 0                         Doug Liman  director
# 0                        Kevin Smith  director
# 0                      Whit Stillman  director
# 0                         Justin Lin  director
# 0                       Peter Hedges  director
# 0                   David O. Russell  director
# 0                  Richard Linklater  director
# 0                  Christopher Nolan  director
#
#                                                 movie  domestic_gross_adj  \
# 0                                           Star Wars       1234649200.00
# 0                                             Titanic       1110191900.00
# 0                                                Jaws       1107881800.00
# 0                         E.T.: The Extra-Terrestrial       1075530900.00
# 0                                       Jurassic Park        745680500.00
# 0           Star Wars: Episode I - The Phantom Menace        733743200.00
# 0                                      Jurassic World        683775600.00
# 0                             The Empire Strikes Back        682158400.00
# 0                                        Forrest Gump        679419600.00
# 0                             Raiders of the Lost Ark        668118400.00
# 0                                       The Lion King        645500900.00
# 0                                             Shrek 2        614590500.00
# 0                                          Spider-Man        601043100.00
# 0                                    Independence Day        599175800.00
# 0                                        Ghostbusters        588942100.00
# 0                                          Home Alone        585900800.00
# 0                                              Batman        544557400.00
# 0       The Lord of the Rings: The Return of the King        532304900.00
# 0                           The Passion of the Christ        515760900.00
# 0        Star Wars: Episode III - Revenge of the Sith        513157600.00
# 0                                  Back to the Future        510788100.00
# 0                                     The Sixth Sense        498059400.00
# 0                                            Superman        496147800.00
# 0               The Lord of the Rings: The Two Towers        495638600.00
# 0                                             Tootsie        492219100.00
# 0                                        Finding Nemo        487319200.00
# 0                                             Twister        473052300.00
# 0                                        Men in Black        472434200.00
# 0   The Lord of the Rings: The Fellowship of the Ring        471163300.00
# 0                Indiana Jones and the Temple of Doom        463058900.00
# ..                                                ...                 ...
# 0                                      Secrets & Lies         25285300.00
# 0                                             Rebound         22683000.00
# 0                              The Kids Are All Right         22643800.00
# 0                                     The Bye Bye Man         22395800.00
# 0                                      Hostel Part II         22139800.00
# 0                                          The Gospel         21291900.00
# 0                                         Blair Witch         21014600.00
# 0                                  The Emperor's Club         20987400.00
# 0                              The Invention of Lying         20972900.00
# 0                     The Secret in their Eyes (2015)         20065700.00
# 0                                      Boys Don't Cry         18774000.00
# 0                                   A Haunted House 2         17995200.00
# 0                                       Super Size Me         16069300.00
# 0                                         Hit and Run         14646700.00
# 0                                 The Wedding Banquet         14486600.00
# 0                                 The Lives of Others         14189700.00
# 0                                            Whiplash         13824600.00
# 0                                        Roger and Me         13736800.00
# 0                                            Cry Wolf         13558900.00
# 0                                   Facing the Giants         13433200.00
# 0                               The Company of Wolves         10695100.00
# 0                                      Blue Valentine         10679900.00
# 0                                            Swingers          8914200.00
# 0                                              Clerks          6520900.00
# 0                                        Metropolitan          6008400.00
# 0                                Better Luck Tomorrow          5454500.00
# 0                                     Pieces of April          3619600.00
# 0                                 Spanking the Monkey          2813800.00
# 0                                             Slacker          2523300.00
# 0                                           Following            82600.00
#
#    release_date  production_budget_adj
# 0    1977-05-25            11000000.00
# 0    1997-12-19           200000000.00
# 0    1975-06-20             7000000.00
# 0    1982-06-11             5000000.00
# 0    1993-06-11            63000000.00
# 0    1999-05-19           115000000.00
# 0    2015-06-12           150000000.00
# 0    1980-05-21            18000000.00
# 0    1994-07-06            55000000.00
# 0    1981-06-12            18000000.00
# 0    1994-06-15            45000000.00
# 0    2004-05-19           150000000.00
# 0    2002-05-03           139000000.00
# 0    1996-07-03            75000000.00
# 0    1984-06-08            30000000.00
# 0    1990-11-16            18000000.00
# 0    1989-06-23            35000000.00
# 0    2003-12-17            94000000.00
# 0    2004-02-25            30000000.00
# 0    2005-05-19           113000000.00
# 0    1985-07-03            19000000.00
# 0    1999-08-06            40000000.00
# 0    1978-12-15            55000000.00
# 0    2002-12-18            94000000.00
# 0    1982-12-17            21000000.00
# 0    2003-05-30            94000000.00
# 0    1996-05-10            92000000.00
# 0    1997-07-02            90000000.00
# 0    2001-12-19            93000000.00
# 0    1984-05-23            28000000.00
# ..          ...                    ...
# 0    1996-09-28             5000000.00
# 0    2005-07-01             1000000.00
# 0    2010-07-09             4000000.00
# 0    2017-01-13             4000000.00
# 0    2007-06-08             2000000.00
# 0    2005-10-07             4000000.00
# 0    2016-09-16             5000000.00
# 0    2002-11-22             5000000.00
# 0    2009-10-02             5000000.00
# 0    2015-11-20             5000000.00
# 0    1999-10-08             2000000.00
# 0    2014-04-18             4000000.00
# 0    2004-05-07               65000.00
# 0    2012-08-22             2000000.00
# 0    1993-08-06             1000000.00
# 0    2007-02-09             2000000.00
# 0    2014-10-10             3000000.00
# 0    1989-12-22              160000.00
# 0    2005-09-16             1000000.00
# 0    2006-09-29              100000.00
# 0    1985-04-19             2000000.00
# 0    2010-12-29             1000000.00
# 0    1996-10-18              200000.00
# 0    1994-10-19               27000.00
# 0    1990-08-03              230000.00
# 0    2003-04-11              250000.00
# 0    2003-10-17              300000.00
# 0    1994-07-15              200000.00
# 0    1991-07-05               23000.00
# 0    1999-04-02                6000.00
#
# [361 rows x 6 columns]

# %%
len(topcrew)
# Out:
# 1572

# %%
# store the date that they were part of a big movie
made_man = topcrew.groupby(['name'])['release_date'].min().reset_index()
made_man.rename(columns={'release_date': 'made_man'}, inplace=True)

# %%
# merge the columns
made_crew = pd.merge(crew, made_man, how='left', on='name')

# %%
# just make sure all the values make sense, but notice that there are duplicates
made_crew[made_crew.name.duplicated()].sort_values('name').head()#.tail()
# Out:
#                 name      role                     movie  domestic_gross_adj  \
# 15591    A.R. Rahman  composer  The Hundred-Foot Journey         58003200.00
# 6098     A.R. Rahman  composer        Million Dollar Arm         37914200.00
# 8835     A.R. Rahman  composer            People Like Us         13825300.00
# 15650  Aaron Eckhart     actor               Nurse Betty         40393500.00
# 11432  Aaron Eckhart     actor                The Pledge         30157500.00
#
#       release_date  production_budget_adj made_man
# 15591   2014-08-08            22000000.00      NaT
# 6098    2014-05-16            25000000.00      NaT
# 8835    2012-06-29            16000000.00      NaT
# 15650   2000-09-08            35000000.00      NaT
# 11432   2001-01-19            35000000.00      NaT

# %%
# drop all NaN values and drop the duplicates with the same name
df_made_crew = made_crew.dropna(subset=['made_man']).drop_duplicates(subset=['name'])

# %%
df_made_crew.head()
# Out:
#                   name      role              movie  domestic_gross_adj  \
# 2      Roland Emmerich  director  Universal Soldier         75661200.00
# 3          Dean Devlin    writer  Universal Soldier         75661200.00
# 5  Darren Lynn Bousman  director             Saw IV         79585200.00
# 6       Leigh Whannell  producer             Saw IV         79585200.00
# 7       Patrick Melton    writer             Saw IV         79585200.00
#
#   release_date  production_budget_adj   made_man
# 2   1992-07-10                    nan 1996-07-03
# 3   1992-07-10                    nan 1996-07-03
# 5   2007-10-26                    nan 2005-10-28
# 6   2007-10-26                    nan 2004-10-29
# 7   2007-10-26                    nan 2008-10-24

# %%
df.head().T
# Out:
#                                                             0  \
# index                  The Other Side of the Mountain Part II
# actors                                                    NaN
# close_date                                                NaT
# composers                                                 NaN
# days_in_theater                                           NaN
# directors                                                 NaN
# domestic_gross_adj                                42753500.00
# foreign_unadj                                             NaN
# genre                                                 Romance
# mpaa_rating                                                PG
# number_of_theaters                                        NaN
# opening_weekend_adj                                       NaN
# producers                                                 NaN
# production_budget_adj                                     NaN
# release_date                              1978-01-01 00:00:00
# runtime                                                100.00
# worldwide_gross_unadj                                     NaN
# writers                                                   NaN
#
#                                                              1  \
# index                                        Universal Soldier
# actors                 [Jean-Claude Van Damme, Dolph Lundgren]
# close_date                                                 NaT
# composers                                        [Tim Simonec]
# days_in_theater                                            NaN
# directors                                    [Roland Emmerich]
# domestic_gross_adj                                 75661200.00
# foreign_unadj                                              NaN
# genre                                            Sci-Fi Action
# mpaa_rating                                                  R
# number_of_theaters                                     1925.00
# opening_weekend_adj                                20962400.00
# producers                                                  NaN
# production_budget_adj                                      NaN
# release_date                               1992-07-10 00:00:00
# runtime                                                 102.00
# worldwide_gross_unadj                                      NaN
# writers                                          [Dean Devlin]
#
#                                          2                    3  \
# index                              Newtown       Mommie Dearest
# actors                                 NaN                  NaN
# close_date                             NaT                  NaT
# composers                              NaN                  NaN
# days_in_theater                      14.00                  NaN
# directors                              NaN                  NaN
# domestic_gross_adj                13900.00          59219100.00
# foreign_unadj                          NaN                  NaN
# genre                          Documentary                Drama
# mpaa_rating                        Unrated                   PG
# number_of_theaters                    3.00                  NaN
# opening_weekend_adj                6700.00                  NaN
# producers                              NaN                  NaN
# production_budget_adj                  NaN                  NaN
# release_date           2016-10-07 00:00:00  1981-09-18 00:00:00
# runtime                              85.00               129.00
# worldwide_gross_unadj                  NaN                  NaN
# writers                                NaN                  NaN
#
#                                                       4
# index                                            G.B.F.
# actors                 [Natasha Lyonne, Megan Mullally]
# close_date                                          NaT
# composers                                           NaN
# days_in_theater                                     NaN
# directors                                           NaN
# domestic_gross_adj                                  NaN
# foreign_unadj                                       NaN
# genre                                            Comedy
# mpaa_rating                                           R
# number_of_theaters                                  NaN
# opening_weekend_adj                                 NaN
# producers                                           NaN
# production_budget_adj                               NaN
# release_date                        2014-01-17 00:00:00
# runtime                                           93.00
# worldwide_gross_unadj                               NaN
# writers                                             NaN

# %%
def checkForQualityCrew(row):
    """
    This calculates the number of actors, directors, and crew were in past high grossing films
    """
#     print(row[0])
    title = row[0]
    rel_date = row[1]

    total = 0
    for role in row[2:]:
        if type(role) == list:
            for name in role:
                role_row = df_made_crew['name'].isin(['Roland Emmerich'])
                isrowempty = role_row.empty
                if (not isrowempty and df_made_crew[role_row].made_man.iloc[0] < rel_date):
                    total += 1
    return total
    

    
made_men_movies = (df[['index','release_date','actors','composers','directors','producers','writers']]
#   .iloc[0:4,:] # this is for testing to control the amount of variables passing into the function
  .apply(checkForQualityCrew,axis=1, raw=True))
#   .sort_values(ascending=False))

# %%
made_men_movies.name = 'made_men'

# %%
new_df = pd.concat([df, made_men_movies], axis=1)

# %%
# save the data frame! :)
# crew.to_pickle('crew.pkl')
