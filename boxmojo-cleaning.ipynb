# %% [markdown]
# # BoxMojo Dataset

# %%
# Data wrangling
import pandas as pd
import numpy as np
import re

# Time
import time
import datetime
from datetime import datetime as dt
import dateutil.parser

# Plotting
import matplotlib.pyplot as plt
import seaborn as sns

# URL Grabbing
import requests

# Scraping / Searching
from bs4 import BeautifulSoup
import re

# Misc
import pickle
from pprint import pprint

# %matplotlib inline
pd.set_option('display.float_format', lambda x: '%.2f' % x) # reduces the amount of decimals when printing the df's

# %% [markdown]
# # Inputting the Data
#
# I was having issues with the way the data was formatted using scrapy, so I just readline by line, then evaluate the JSON since it works as a python dictionary.

# %%
filename = 'test_run.jl'
filename_r = './bomojo_scrap/' + filename

with open(filename_r, 'r') as fh:
    fstr = fh.readlines()

# %%
# this was a test string to find an issue with the eval statement, use this if you can figure it out! :)
# test_str = '{"The Boxtrolls": {"domestic_gross_adj": "$52,992,000", "foreign_unadj": "\u00a0$58,447,728", "worldwide_gross_unadj": "$109,285,033", "release_date": "September 26, 2014", "genre": "Animation", "runtime": "1 hrs. 37 min.", "mpaa_rating": "PG", "production_budget_adj": "$60 million", "opening_weekend_adj": "\u00a0$18,493,900", "number_of_theaters": "\u00a03,464 theaters", "close_date": "\u00a0February 5, 2015", "days_in_theater": "\u00a0133 days / 19 weeks", "directors": ["Graham Annable", "Anthony Stacchi"], "writers": ["Irena Brignull", "Adam Pava"], "actors": ["Ben Kingsley", "Toni Collette", "Elle Fanning", "Jared Harris", "Simon Pegg", "Nick Frost", "Richard Ayoade ", "Tracy Morgan"], "producers": ["Travis Knight"], "composers": ["Dario Marianelli"]}}'

# %%
# grabs all the movies
movies = fstr

# replaces all 'null' strings with "null" because when evaluating the expression, it can't use the keyword null
movies = [x.replace('null','"null"') for x in movies]

# evaluates the expression to be a list of dicts!
# movies_eval = [eval(x) for x in movies]
movies_eval = []

print('Lines causing eval errors:\n')
for movie_json in movies:
    try:
        movies_eval.append(eval(movie_json))
    except:
        print(movie_json)
# Out:
# Lines causing eval errors:
#
# {"The Boxtrolls": {"domestic_gross_adj": "$52,992,000", "foreign_unadj": "\u00a0$58,447,728", "worldwide_gross_unadj": "$109,285,033", "release_date": "September 26, 2014", "genre": "Animation", "runtime": "1 hrs. 37 min.", "mpaa_rating": "PG", "production_budget_adj": "$60 million", "opening_weekend_adj": "\u00a0$18,493,900", "number_of_theaters": "\u00a03,464 theaters", "close_date": "\u00a0February 5, 2015", "days_in_theater": "\u00a0133 days / 19 weeks", "directors": ["Graham Annable", "Anthony Stacchi"], "writers": ["Irena Brig"null"", "Adam Pava"], "actors": ["Ben Kingsley", "Toni Collette", "Elle Fanning", "Jared Harris", "Simon Pegg", "Nick Frost", "Richard Ayoade ", "Tracy Morgan"], "producers": ["Travis Knight"], "composers": ["Dario Marianelli"]}}

# %%
# creates a DataFrame for each of the dictionaries in the eval and concats them all
df = pd.concat([pd.DataFrame(x) for x in movies_eval], axis=1)

# %%
# transposes the columns and the index
df = df.T

# %% [markdown]
# # Checking the data

# %%
# check columns for any problems
df.columns
# Out:
# Index(['actors', 'close_date', 'composers', 'days_in_theater', 'directors',
#        'domestic_gross_adj', 'foreign_unadj', 'genre', 'mpaa_rating',
#        'number_of_theaters', 'opening_weekend_adj', 'producers',
#        'production_budget_adj', 'release_date', 'runtime',
#        'worldwide_gross_unadj', 'writers'],
#       dtype='object')

# %%
# make sure all the data was imported
df.count()
# Out:
# actors                   9965
# close_date               9965
# composers                9965
# days_in_theater          9965
# directors                9965
# domestic_gross_adj       9965
# foreign_unadj            9965
# genre                    9965
# mpaa_rating              9965
# number_of_theaters       9965
# opening_weekend_adj      9965
# producers                9965
# production_budget_adj    9965
# release_date             9965
# runtime                  9965
# worldwide_gross_unadj    9965
# writers                  9965
# dtype: int64

# %%
# taking a peek into the data
df.head().T
# Out:
#                       The Other Side of the Mountain Part II  \
# actors                                                    []
# close_date                                              null
# composers                                                 []
# days_in_theater                                         null
# directors                                                 []
# domestic_gross_adj                               $42,753,500
# foreign_unadj                                           null
# genre                                                Romance
# mpaa_rating                                               PG
# number_of_theaters                                      null
# opening_weekend_adj                                     null
# producers                                                 []
# production_budget_adj                                    N/A
# release_date                                 January 1, 1978
# runtime                                       1 hrs. 40 min.
# worldwide_gross_unadj                                   null
# writers                                                   []
#
#                                              Universal Soldier  \
# actors                 [Jean-Claude Van Damme, Dolph Lundgren]
# close_date                                                null
# composers                                        [Tim Simonec]
# days_in_theater                                           null
# directors                                    [Roland Emmerich]
# domestic_gross_adj                                 $75,661,200
# foreign_unadj                                             null
# genre                                            Sci-Fi Action
# mpaa_rating                                                  R
# number_of_theaters                              1,925 theaters
# opening_weekend_adj                                $20,962,400
# producers                                                   []
# production_budget_adj                                      N/A
# release_date                                     July 10, 1992
# runtime                                         1 hrs. 42 min.
# worldwide_gross_unadj                                     null
# writers                                          [Dean Devlin]
#
#                                   Newtown      Mommie Dearest  \
# actors                                 []                  []
# close_date                           null                null
# composers                              []                  []
# days_in_theater         14 days / 2 weeks                null
# directors                              []                  []
# domestic_gross_adj                $13,900         $59,219,100
# foreign_unadj                        null                null
# genre                         Documentary               Drama
# mpaa_rating                       Unrated                  PG
# number_of_theaters             3 theaters                null
# opening_weekend_adj                $6,700                null
# producers                              []                  []
# production_budget_adj                 N/A                 N/A
# release_date              October 7, 2016  September 18, 1981
# runtime                    1 hrs. 25 min.       2 hrs. 9 min.
# worldwide_gross_unadj                null                null
# writers                                []                  []
#
#                                                  G.B.F.
# actors                 [Natasha Lyonne, Megan Mullally]
# close_date                                         null
# composers                                            []
# days_in_theater                                    null
# directors                                            []
# domestic_gross_adj                                 null
# foreign_unadj                                      null
# genre                                            Comedy
# mpaa_rating                                           R
# number_of_theaters                                 null
# opening_weekend_adj                                null
# producers                                            []
# production_budget_adj                               N/A
# release_date                           January 17, 2014
# runtime                                  1 hrs. 33 min.
# worldwide_gross_unadj                              null
# writers                                              []

# %%
# looks like I need to manually convert a lot of these into their respective format
df.dtypes
# Out:
# actors                   object
# close_date               object
# composers                object
# days_in_theater          object
# directors                object
# domestic_gross_adj       object
# foreign_unadj            object
# genre                    object
# mpaa_rating              object
# number_of_theaters       object
# opening_weekend_adj      object
# producers                object
# production_budget_adj    object
# release_date             object
# runtime                  object
# worldwide_gross_unadj    object
# writers                  object
# dtype: object

# %%
# looks like I have a lot of duplicated indexes, so will just reset index to handle
    df[df.index.duplicated()].T
# Out:
#                             The Karate Kid Kicking and Screaming  \
# actors                                  []        [Parker Posey]
# close_date                            null        April 11, 1996
# composers                               []                    []
# days_in_theater                       null                  null
# directors                               []       [Noah Baumbach]
# domestic_gross_adj            $233,796,000            $1,428,700
# foreign_unadj                         null                  null
# genre                        Sports Action                Comedy
# mpaa_rating                             PG                     R
# number_of_theaters          1,111 theaters           26 theaters
# opening_weekend_adj            $12,953,800                  null
# producers                               []                    []
# production_budget_adj                  N/A                   N/A
# release_date                 June 22, 1984       October 6, 1995
# runtime                      2 hrs. 7 min.        1 hrs. 36 min.
# worldwide_gross_unadj                 null                  null
# writers                [Robert Mark Kamen]       [Noah Baumbach]
#
#                              After Midnight          Together  \
# actors                                   []                []
# close_date                   August 7, 2005   October 9, 2003
# composers                                []                []
# days_in_theater         119 days / 17 weeks              null
# directors                                []                []
# domestic_gross_adj                  $68,900        $1,652,500
# foreign_unadj                    $1,525,534       $13,535,226
# genre                               Foreign           Foreign
# mpaa_rating                         Unrated                PG
# number_of_theaters               3 theaters       47 theaters
# opening_weekend_adj                 $10,600           $99,300
# producers                                []                []
# production_budget_adj                   N/A               N/A
# release_date               December 3, 2004      May 30, 2003
# runtime                      1 hrs. 29 min.    1 hrs. 56 min.
# worldwide_gross_unadj            $1,576,003       $14,687,167
# writers                                  []                []
#
#                             Three of Hearts  \
# actors                                   []
# close_date                 December 8, 2005
# composers                                []
# days_in_theater         51 days / 7.3 weeks
# directors                                []
# domestic_gross_adj                  $28,900
# foreign_unadj                          null
# genre                           Documentary
# mpaa_rating                         Unrated
# number_of_theaters               1 theaters
# opening_weekend_adj                  $6,000
# producers                                []
# production_budget_adj                   N/A
# release_date               October 19, 2005
# runtime                      1 hrs. 37 min.
# worldwide_gross_unadj                  null
# writers                                  []
#
#                                              When a Stranger Calls  \
# actors                 [Camilla Belle, Katie Cassidy, Clark Gregg]
# close_date                                          March 19, 2006
# composers                                                       []
# days_in_theater                                  49 days / 7 weeks
# directors                                             [Simon West]
# domestic_gross_adj                                     $63,204,700
# foreign_unadj                                          $19,106,773
# genre                                              Horror Thriller
# mpaa_rating                                                  PG-13
# number_of_theaters                                  3,004 theaters
# opening_weekend_adj                                    $28,534,700
# producers                               [John Davis, Wyck Godfrey]
# production_budget_adj                                  $15 million
# release_date                                      February 3, 2006
# runtime                                             1 hrs. 40 min.
# worldwide_gross_unadj                                  $66,966,987
# writers                                                         []
#
#                                                                   Legend  \
# actors                 [Emily Browning, Christopher Eccleston, Taron ...
# close_date                                               January 7, 2016
# composers                                               [Carter Burwell]
# days_in_theater                                        49 days / 7 weeks
# directors                                              [Brian Helgeland]
# domestic_gross_adj                                            $1,862,500
# foreign_unadj                                                $41,100,000
# genre                                                        Crime Drama
# mpaa_rating                                                            R
# number_of_theaters                                          107 theaters
# opening_weekend_adj                                              $86,300
# producers                                                             []
# production_budget_adj                                                N/A
# release_date                                           November 20, 2015
# runtime                                                   2 hrs. 11 min.
# worldwide_gross_unadj                                        $42,972,994
# writers                                                [Brian Helgeland]
#
#                          The Animation Show  \
# actors                                   []
# close_date                             null
# composers                                []
# days_in_theater         59 days / 8.4 weeks
# directors                                []
# domestic_gross_adj                 $332,700
# foreign_unadj                          null
# genre                             Animation
# mpaa_rating                         Unrated
# number_of_theaters               6 theaters
# opening_weekend_adj                    null
# producers                                []
# production_budget_adj                   N/A
# release_date              February 18, 2005
# runtime                      1 hrs. 25 min.
# worldwide_gross_unadj                  null
# writers                                  []
#
#                                            Freaky Friday Happily Ever After  \
# actors                 [Lindsay Lohan, Jamie Lee Curtis]                 []
# close_date                              January 15, 2004               null
# composers                                   [Rolfe Kent]                 []
# days_in_theater                    163 days / 23.3 weeks               null
# directors                               [Mark S. Waters]                 []
# domestic_gross_adj                          $158,113,900         $6,893,600
# foreign_unadj                                $50,616,000               null
# genre                                     Fantasy Comedy          Animation
# mpaa_rating                                           PG                  G
# number_of_theaters                        3,067 theaters     1,018 theaters
# opening_weekend_adj                          $31,850,100         $3,669,000
# producers                                             []                 []
# production_budget_adj                        $20 million                N/A
# release_date                              August 6, 2003       May 28, 1993
# runtime                                   1 hrs. 37 min.     1 hrs. 14 min.
# worldwide_gross_unadj                       $160,846,332               null
# writers                     [Leslie Dixon, Heather Hach]                 []
#
#                                                        Renegades  \
# actors                 [Kiefer Sutherland, Lou Diamond Phillips]
# close_date                                                  null
# composers                                        [Michael Kamen]
# days_in_theater                                             null
# directors                                                     []
# domestic_gross_adj                                   $19,642,600
# foreign_unadj                                               null
# genre                                              Action Comedy
# mpaa_rating                                                    R
# number_of_theaters                                1,627 theaters
# opening_weekend_adj                                   $6,700,000
# producers                                  [Ted Field, Joe Roth]
# production_budget_adj                                        N/A
# release_date                                        June 2, 1989
# runtime                                           1 hrs. 46 min.
# worldwide_gross_unadj                                       null
# writers                                                       []
#
#                                                    Hero  \
# actors                 [Donnie Yen, Jet Li, Zhang Ziyi]
# close_date                            November 25, 2004
# composers                                     [Tan Dun]
# days_in_theater                                    null
# directors                                 [Zhang Yimou]
# domestic_gross_adj                          $74,813,500
# foreign_unadj                              $123,684,413
# genre                                  Foreign / Action
# mpaa_rating                                       PG-13
# number_of_theaters                       2,175 theaters
# opening_weekend_adj                         $25,078,500
# producers                           [Quentin Tarantino]
# production_budget_adj                       $31 million
# release_date                            August 27, 2004
# runtime                                  1 hrs. 39 min.
# worldwide_gross_unadj                      $177,394,432
# writers                                              []
#
#                                     Running Scared
# actors                 [Paul Walker, Vera Farmiga]
# close_date                           April 2, 2006
# composers                             [Mark Isham]
# days_in_theater                  42 days / 6 weeks
# directors                           [Wayne Kramer]
# domestic_gross_adj                      $9,053,000
# foreign_unadj                           $2,524,892
# genre                               Action / Crime
# mpaa_rating                                      R
# number_of_theaters                  1,611 theaters
# opening_weekend_adj                     $4,466,300
# producers                                       []
# production_budget_adj                  $15 million
# release_date                     February 24, 2006
# runtime                             1 hrs. 50 min.
# worldwide_gross_unadj                   $9,380,029
# writers                             [Wayne Kramer]

# %% [markdown]
# # Cleaning the data

# %%
# reset the index
df = df.reset_index()

# Replaces all unknown values
df.replace('null', np.nan, inplace=True)
df.replace('N/A', np.nan, inplace=True)
df['genre'].replace('Unknown', np.nan, inplace=True)
df['mpaa_rating'].replace('Unknown', np.nan, inplace=True)
df['release_date'].replace('TBD', np.nan, inplace=True)
df['foreign_unadj'].replace('n/a', np.nan, inplace=True)

# remove things like '2018'
df['release_date'].replace(re.compile(r'^\d+$'), np.nan, inplace=True)

# remove things like 'July 1994'
df['release_date'].replace(re.compile(r'^^\w+\s+\d+$'), np.nan, inplace=True)

# removes encoded characters 
# .replace('\\xa0', '', inplace=True) didn't work as well as passing in the argument re.compile(r'^\\xa0')
df['close_date'] = df['close_date'].str.strip()

# %%
# Removes all empty arrays.
# **This will break if done twice!
df['actors'] = df['actors'].apply(lambda x: np.nan if len(x)==0 else x)
df['composers'] = df['composers'].apply(lambda x: np.nan if len(x)==0 else x)
df['directors'] = df['directors'].apply(lambda x: np.nan if len(x)==0 else x)
df['producers'] = df['producers'].apply(lambda x: np.nan if len(x)==0 else x)
df['writers'] = df['writers'].apply(lambda x: np.nan if len(x)==0 else x)

# %%
# Checking encoded characters are removed
mask = df['close_date'] == '\xa0December 13, 2007'
df[mask]
# Out:
# Empty DataFrame
# Columns: [index, actors, close_date, composers, days_in_theater, directors, domestic_gross_adj, foreign_unadj, genre, mpaa_rating, number_of_theaters, opening_weekend_adj, producers, production_budget_adj, release_date, runtime, worldwide_gross_unadj, writers]
# Index: []

# %% [markdown]
# # Transformation

# %%
# changing the release date to a datetime
df['release_date'] = pd.to_datetime(df['release_date'], format="%B %d, %Y");
df['close_date'] = pd.to_datetime(df['close_date'], format="%B %d, %Y");

# %%
# remove everything after days and the whitespace before it
df['days_in_theater'] = df['days_in_theater'].replace(re.compile('\sdays.*'), '')

# kill the commas
df['days_in_theater'] = df['days_in_theater'].replace(re.compile(','), '')

# strip any whitespace
df['days_in_theater'] = df['days_in_theater'].str.strip()

# convert values to ints
# df['days_in_theater'] = df[df['days_in_theater'].notnull()]['days_in_theater'].apply(lambda days: int(days))
df['days_in_theater'] = pd.to_numeric(df['days_in_theater'], errors='coerce', downcast='integer')

# %%
# remove the dollar signs
df['domestic_gross_adj'] = df['domestic_gross_adj'].replace(re.compile('\$'), '')

# remove the commas
df['domestic_gross_adj'] = df['domestic_gross_adj'].replace(re.compile(','), '')

# kill any encoded whitespace, or whitespace
df['domestic_gross_adj'] = df['domestic_gross_adj'].str.strip()

# convert to int
# df['domestic_gross_adj'] = df[df['domestic_gross_adj'].notnull()]['domestic_gross_adj'].apply(lambda days: int(days))
df['domestic_gross_adj'] = pd.to_numeric(df['domestic_gross_adj'], errors='coerce')

# %%
# remove the dollar signs
df['foreign_unadj'] = df['foreign_unadj'].replace(re.compile('\$'), '')

# remove the commas
df['foreign_unadj'] = df['foreign_unadj'].replace(re.compile(','), '')

# kill any encoded whitespace, or whitespace
df['foreign_unadj'] = df['foreign_unadj'].str.strip()

# convert to int
# df['foreign_unadj'] = df[df['foreign_unadj'].notnull()]['foreign_unadj'].apply(lambda days: int(days))
df['foreign_unadj'] = pd.to_numeric(df['foreign_unadj'], errors='coerce')

# %%
df['number_of_theaters'] = df['number_of_theaters'].replace(re.compile(r'\stheaters'), '')
df['number_of_theaters'] = df['number_of_theaters'].replace(re.compile(','), '')
df['number_of_theaters'] = df['number_of_theaters'].str.strip()
# df['number_of_theaters'] = df[df['number_of_theaters'].notnull()]['number_of_theaters'].apply(lambda days: int(days)) 
df['number_of_theaters'] = pd.to_numeric(df['number_of_theaters'], errors='coerce')

# %%
df['opening_weekend_adj'] = df['opening_weekend_adj'].replace(re.compile('\$'), '')
df['opening_weekend_adj'] = df['opening_weekend_adj'].replace(re.compile(','), '')
df['opening_weekend_adj'] = df['opening_weekend_adj'].str.strip()
df['opening_weekend_adj'] = pd.to_numeric(df['opening_weekend_adj'], errors='coerce')

# %%
# # prototyping the millionOrThousand function

# string = '1223'
# million = re.compile(r'(\d+)\s(million)')
# thousand = re.compile(r'(^\d+$)')

# millions = re.findall(million, string)
# thousands = re.findall(thousand, string)

# if millions:
#     print('million')
# if thousands:
#     print('thousand')
    
# thousands[0]

# %%
def millionOrThousand(string):
    '''Returns a integer 
    '''
    strng = str(string)
    million = re.compile(r'(\d+)\s(million)')
    thousand = re.compile(r'(^\d+$)')
    
    thousands = re.findall(thousand, strng)
    millions = re.findall(million, strng)
    
    if millions:
        return int(float(millions[0][0]) * 1000000)
    elif thousands:
        return int(thousands[0])

# # production budget -> integer
df['production_budget_adj'] = df['production_budget_adj'].replace(re.compile('\$'), '')
df['production_budget_adj'] = df['production_budget_adj'].replace(re.compile(','), '')
df['production_budget_adj'] = df['production_budget_adj'].str.strip()
df['production_budget_adj'] = (df['production_budget_adj'].dropna().apply(millionOrThousand).astype(np.int))

# %%
def hoursAndMins(string):
    string = str(string)
    r_hrsmins = re.compile(r'(^\d+)\shrs\.\s(\d+)')
    hrsmins = r_hrsmins.findall(string)

    if hrsmins:
        hrs = int(hrsmins[0][0]) * 60
        mins = int(hrsmins[0][1])
        return int(hrs + mins)
    else:
        return np.nan
    
df['runtime'] = df['runtime'].apply(hoursAndMins)

# %%
# worldwide gross -> integer

# remove the dollar signs
df['worldwide_gross_unadj'] = df['worldwide_gross_unadj'].replace(re.compile('\$'), '')

# remove the commas
df['worldwide_gross_unadj'] = df['worldwide_gross_unadj'].replace(re.compile(','), '')

# kill any encoded whitespace, or whitespace
df['worldwide_gross_unadj'] = df['worldwide_gross_unadj'].str.strip()

# convert to int
# df['domestic_gross_adj'] = df[df['domestic_gross_adj'].notnull()]['domestic_gross_adj'].apply(lambda days: int(days))
df['worldwide_gross_unadj'] = pd.to_numeric(df['worldwide_gross_unadj'], errors='coerce')

# %% [markdown]
# # Confirming the data looks good

# %%
# check columns for any problems
df.columns
# Out:
# Index(['index', 'actors', 'close_date', 'composers', 'days_in_theater',
#        'directors', 'domestic_gross_adj', 'foreign_unadj', 'genre',
#        'mpaa_rating', 'number_of_theaters', 'opening_weekend_adj', 'producers',
#        'production_budget_adj', 'release_date', 'runtime',
#        'worldwide_gross_unadj', 'writers'],
#       dtype='object')

# %%
df.dtypes
# Out:
# index                            object
# actors                           object
# close_date               datetime64[ns]
# composers                        object
# days_in_theater                 float64
# directors                        object
# domestic_gross_adj              float64
# foreign_unadj                   float64
# genre                            object
# mpaa_rating                      object
# number_of_theaters              float64
# opening_weekend_adj             float64
# producers                        object
# production_budget_adj           float64
# release_date             datetime64[ns]
# runtime                         float64
# worldwide_gross_unadj           float64
# writers                          object
# dtype: object

# %%
df.describe()
# Out:
#        days_in_theater  domestic_gross_adj  foreign_unadj  number_of_theaters  \
# count          5745.00             9470.00        4047.00             9086.00
# mean             85.60         36773478.15    60885921.46              958.04
# std             103.56         77886268.39   119104852.31             1217.06
# min            -168.00              100.00          29.00                1.00
# 25%              28.00           115525.00     2481470.50                9.00
# 50%              70.00          2838650.00    16002944.00              129.00
# 75%             119.00         40450025.00    64375453.00             1862.75
# max            3934.00       1234649200.00  2027457462.00             4468.00
#
#        opening_weekend_adj  production_budget_adj  runtime  \
# count              8417.00                2419.00  9557.00
# mean            9238846.09            48340876.05   104.52
# std            19096666.27            47608964.42    22.05
# min                 100.00                 220.00    37.00
# 25%               16000.00            15000000.00    91.00
# 50%              228700.00            32000000.00   100.00
# 75%            11485800.00            68000000.00   113.00
# max           246541600.00           300000000.00   583.00
#
#        worldwide_gross_unadj
# count                5080.00
# mean             86222892.04
# std             170096362.46
# min                    29.00
# 25%               1231547.25
# 50%              19594619.50
# 75%              96617784.00
# max            2787965087.00

# %%
df[['close_date', 'release_date', 'genre', 'mpaa_rating']].describe()
# Out:
#                  close_date         release_date    genre mpaa_rating
# count                  5982                 9829     9308        9927
# unique                 1691                 2778       65           8
# top     2011-09-29 00:00:00  2013-09-06 00:00:00  Foreign           R
# freq                     20                   19     1619        3217
# first   1982-03-18 00:00:00  1921-03-06 00:00:00      NaN         NaN
# last    2017-04-06 00:00:00  2023-06-30 00:00:00      NaN         NaN

# %%
# the original star wars film
# http://www.boxofficemojo.com/movies/?id=starwars4.htm&adjust_yr=2017&p=.htm
df[df['domestic_gross_adj'] == 1234649200.00]
# Out:
#           index                                             actors close_date  \
# 8577  Star Wars  [Kenny Baker, Anthony Daniels, Alec Guinness, ...        NaT
#
#             composers  days_in_theater       directors  domestic_gross_adj  \
# 8577  [John Williams]              nan  [George Lucas]       1234649200.00
#
#       foreign_unadj           genre mpaa_rating  number_of_theaters  \
# 8577   314400000.00  Sci-Fi Fantasy          PG             1750.00
#
#       opening_weekend_adj       producers  production_budget_adj release_date  \
# 8577                  nan  [George Lucas]            11000000.00   1977-05-25
#
#       runtime  worldwide_gross_unadj         writers
# 8577   121.00           775398007.00  [George Lucas]

# %%
# lol... twilight
df[df['number_of_theaters'] == 4468.00]
# Out:
#                            index  \
# 3177  The Twilight Saga: Eclipse
#
#                                                  actors close_date  \
# 3177  [Kristen Stewart, Robert Pattinson, Taylor Lau... 2010-10-21
#
#            composers  days_in_theater      directors  domestic_gross_adj  \
# 3177  [Howard Shore]           114.00  [David Slade]        326993600.00
#
#       foreign_unadj    genre mpaa_rating  number_of_theaters  \
# 3177   397959596.00  Romance       PG-13             4468.00
#
#       opening_weekend_adj                                     producers  \
# 3177          72736500.00  [Marty Bowen, Wyck Godfrey, Karen Rosenfelt]
#
#       production_budget_adj release_date  runtime  worldwide_gross_unadj  \
# 3177            68000000.00   2010-06-30   124.00           698491347.00
#
#                   writers
# 3177  [Melissa Rosenberg]

# %%
# the star wars franchise seems incredibly successful
df[df['opening_weekend_adj'] == 246541600.00]
# Out:
#                              index  \
# 3438  Star Wars: The Force Awakens
#
#                                                  actors close_date  \
# 3438  [John Boyega, Daisy Ridley, Adam Driver, Oscar... 2016-06-02
#
#             composers  days_in_theater      directors  domestic_gross_adj  \
# 3438  [John Williams]           168.00  [J.J. Abrams]        935195600.00
#
#       foreign_unadj           genre mpaa_rating  number_of_theaters  \
# 3438  1131561399.00  Sci-Fi Fantasy       PG-13             4134.00
#
#       opening_weekend_adj                                    producers  \
# 3438         246541600.00  [J.J. Abrams, Bryan Burk, Kathleen Kennedy]
#
#       production_budget_adj release_date  runtime  worldwide_gross_unadj  \
# 3438           245000000.00   2015-12-18   136.00          2068223624.00
#
#                                             writers
# 3438  [J.J. Abrams, Michael Arndt, Lawrence Kasdan]

# %%
# make sure all the data was imported
df.count()
# Out:
# index                    9965
# actors                   4648
# close_date               5982
# composers                2552
# days_in_theater          5745
# directors                3491
# domestic_gross_adj       9470
# foreign_unadj            4047
# genre                    9308
# mpaa_rating              9927
# number_of_theaters       9086
# opening_weekend_adj      8417
# producers                2926
# production_budget_adj    2419
# release_date             9829
# runtime                  9557
# worldwide_gross_unadj    5080
# writers                  2375
# dtype: int64

# %%
df['runtime'].describe()
# Out:
# count   9557.00
# mean     104.52
# std       22.05
# min       37.00
# 25%       91.00
# 50%      100.00
# 75%      113.00
# max      583.00
# Name: runtime, dtype: float64

# %%
# the 583 is a movie called dekalog, a polish tv series
df[df['runtime'] == 583.00]
# Out:
#                           index actors close_date composers  days_in_theater  \
# 5107  Dekalog (2016 re-release)    NaN        NaT       NaN            35.00
#
#      directors  domestic_gross_adj  foreign_unadj  genre mpaa_rating  \
# 5107       NaN           107800.00            nan  Drama     Unrated
#
#       number_of_theaters  opening_weekend_adj producers  \
# 5107                5.00             18800.00       NaN
#
#       production_budget_adj release_date  runtime  worldwide_gross_unadj  \
# 5107                    nan   2016-09-02   583.00                    nan
#
#      writers
# 5107     NaN

# %%
df['mpaa_rating'].value_counts()
# Out:
# R                3217
# Unrated          2826
# PG-13            2007
# PG               1353
# G                 262
# Not Yet Rated     239
# NC-17              21
# M                   2
# Name: mpaa_rating, dtype: int64

# %% [markdown]
# # Looks good, Pickle it

# %%
with open('movies.pkl', 'wb') as picklefile:
    pickle.dump(df, picklefile)
